# %%
import os as o
c=o.getcwd()
c
# Out:
# 'C:\\Users\\ELCOT'

# %%
ch=o.chdir(r'C:\Users\ELCOT\Downloads')
ch
c=o.getcwd()
c
# Out:
# 'C:\\Users\\ELCOT\\Downloads'

# %%
import pandas as pd
data=pd.read_csv('pd.csv')
data
# Out:
#      transaction_id customer_id signup_date transaction_date region  \
# 0          TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1          TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2          TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3          TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4          TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ...             ...         ...         ...              ...    ...
# 998        TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999        TXN_1999     CUST_29  2023-06-16       2024-06-01  South
# 1000       TXN_1010    CUST_117  2023-04-24       2024-06-09  South
# 1001       TXN_1025     CUST_59  2023-06-27       2024-09-19   West
# 1002       TXN_1040     CUST_14  2023-04-07       2024-02-11   East
#
#          category product_name   price  quantity  discount payment_method  \
# 0          Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
#find missing values::

print("no of rows and columns:",data.shape)
print("find null values in each columns:",data.isnull().sum())
print("find each column in null rows:",data.loc[data['discount'].isnull()])
# Out:
# no of rows and columns: (1003, 12)
# find null values in each columns: transaction_id       0
# customer_id          0
# signup_date          0
# transaction_date     0
# region               0
# category             0
# product_name         0
# price                0
# quantity             0
# discount            48
# payment_method      61
# customer_rating     43
# dtype: int64
# find each column in null rows:     transaction_id customer_id signup_date transaction_date region  \
# 11        TXN_1011    CUST_100  2023-08-10       2024-04-28  South
# 17        TXN_1017     CUST_88  2023-12-25       2024-01-11   West
# 26        TXN_1026     CUST_15  2023-12-15       2024-03-25  North
# 59        TXN_1059     CUST_54  2023-03-26       2024-01-27  South
# 69        TXN_1069     CUST_53  2023-01-11       2024-09-15  South
# 91        TXN_1091    CUST_135  2023-08-12       2024-04-15  South
# 120       TXN_1120     CUST_36  2023-02-03       2024-02-07  South
# ...

# %%
print("find duplicated records count:",data.duplicated().sum())
# Out:
# find duplicated records count: 3

# %%
print("find duplicated records count:",data.loc[data.duplicated()])
# Out:
# find duplicated records count:      transaction_id customer_id signup_date transaction_date region  category  \
# 1000       TXN_1010    CUST_117  2023-04-24       2024-06-09  South  Clothing
# 1001       TXN_1025     CUST_59  2023-06-27       2024-09-19   West    Beauty
# 1002       TXN_1040     CUST_14  2023-04-07       2024-02-11   East      Home
#
#      product_name   price  quantity  discount payment_method  customer_rating
# 1000       Prod_D  162.97         5       0.1    Credit Card              4.0
# 1001       Prod_D  295.88         2       0.0           Cash              3.0
# 1002       Prod_D  404.75         4       0.0    Net Banking              3.0

# %%
#data cleaning::

data= data.drop_duplicates()
data
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ..             ...         ...         ...              ...    ...
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
print(data.duplicated().sum())
print(data.loc[data.duplicated()])
# Out:
# 0
# Empty DataFrame
# Columns: [transaction_id, customer_id, signup_date, transaction_date, region, category, product_name, price, quantity, discount, payment_method, customer_rating]
# Index: []

# %%
#convert datatype str to datetime::
print(data.dtypes)
# Out:
# transaction_id          str
# customer_id             str
# signup_date             str
# transaction_date        str
# region                  str
# category                str
# product_name            str
# price               float64
# quantity              int64
# discount            float64
# payment_method          str
# customer_rating     float64
# dtype: object

# %%
data['signup_date']=pd.to_datetime(data['signup_date'])
data
print(data.dtypes)
# Out:
# transaction_id                 str
# customer_id                    str
# signup_date         datetime64[us]
# transaction_date               str
# region                         str
# category                       str
# product_name                   str
# price                      float64
# quantity                     int64
# discount                   float64
# payment_method                 str
# customer_rating            float64
# dtype: object

# %%
data['transaction_date']=pd.to_datetime(data['transaction_date'])
data
print(data.dtypes)
# Out:
# transaction_id                 str
# customer_id                    str
# signup_date         datetime64[us]
# transaction_date    datetime64[us]
# region                         str
# category                       str
# product_name                   str
# price                      float64
# quantity                     int64
# discount                   float64
# payment_method                 str
# customer_rating            float64
# dtype: object

# %%
print(data.isnull().sum())
# Out:
# transaction_id       0
# customer_id          0
# signup_date          0
# transaction_date     0
# region               0
# category             0
# product_name         0
# price                0
# quantity             0
# discount            48
# payment_method      61
# customer_rating     43
# dtype: int64

# %%
# handle null values:::

data['discount']=data['discount'].fillna(0)
print(data.isnull().sum())
# Out:
# transaction_id       0
# customer_id          0
# signup_date          0
# transaction_date     0
# region               0
# category             0
# product_name         0
# price                0
# quantity             0
# discount             0
# payment_method      61
# customer_rating     43
# dtype: int64

# %%
data['payment_method']=data['payment_method'].fillna('unknown')
print(data.isnull().sum())
# Out:
# transaction_id       0
# customer_id          0
# signup_date          0
# transaction_date     0
# region               0
# category             0
# product_name         0
# price                0
# quantity             0
# discount             0
# payment_method       0
# customer_rating     43
# dtype: int64

# %%
data['customer_rating']=data['customer_rating'].fillna(data['customer_rating'].median())
print(data.isnull().sum())
# Out:
# transaction_id      0
# customer_id         0
# signup_date         0
# transaction_date    0
# region              0
# category            0
# product_name        0
# price               0
# quantity            0
# discount            0
# payment_method      0
# customer_rating     0
# dtype: int64

# %%
print(data.isnull().sum())
# Out:
# transaction_id      0
# customer_id         0
# signup_date         0
# transaction_date    0
# region              0
# category            0
# product_name        0
# price               0
# quantity            0
# discount            0
# payment_method      0
# customer_rating     0
# dtype: int64

# %%
data
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ..             ...         ...         ...              ...    ...
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
print(data.head(2))
# Out:
#   transaction_id customer_id signup_date transaction_date region category  \
# 0       TXN_1000    CUST_103  2023-11-01       2024-07-20  North   Sports
# 1       TXN_1001     CUST_93  2023-10-13       2024-12-10  North     Home
#
#   product_name   price  quantity  discount payment_method  customer_rating
# 0       Prod_B  248.82         4      0.20    Net Banking              2.0
# 1       Prod_D  348.79         5      0.05            UPI              4.0

# %%
print(data.tail(2))
# Out:
#     transaction_id customer_id signup_date transaction_date region  category  \
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North  Clothing
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South  Clothing
#
#     product_name   price  quantity  discount payment_method  customer_rating
# 998       Prod_B   12.39         5      0.05            UPI              5.0
# 999       Prod_D  212.21         2      0.05            UPI              4.0

# %%
print(data.shape)
# Out:
# (1000, 12)

# %%
f=data['customer_rating'].median()
f
# Out:
# np.float64(4.0)

# %%
f=data.loc[data['discount']==0]
f
# Out:
#     transaction_id customer_id signup_date transaction_date region  category  \
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East      Home
# 11        TXN_1011    CUST_100  2023-08-10       2024-04-28  South      Home
# 13        TXN_1013    CUST_131  2023-11-15       2024-05-29  South    Beauty
# 16        TXN_1016      CUST_2  2023-02-24       2024-06-08   West    Beauty
# 17        TXN_1017     CUST_88  2023-12-25       2024-01-11   West    Beauty
# ..             ...         ...         ...              ...    ...       ...
# 988       TXN_1988    CUST_118  2023-07-27       2024-03-07  North  Clothing
# 993       TXN_1993     CUST_71  2023-03-09       2024-12-26   East    Beauty
# 994       TXN_1994      CUST_1  2023-02-19       2024-09-13  South    Sports
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West    Sports
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North  Clothing
#
# ...

# %%
f=data.loc[data['customer_rating']<4]
f
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# 5         TXN_1005     CUST_21  2023-09-14       2024-03-09  South
# ..             ...         ...         ...              ...    ...
# 987       TXN_1987    CUST_148  2023-06-01       2024-03-16   West
# 988       TXN_1988    CUST_118  2023-07-27       2024-03-07  North
# 991       TXN_1991    CUST_104  2023-12-13       2024-06-10   East
# 993       TXN_1993     CUST_71  2023-03-09       2024-12-26   East
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
f=data.loc[data['customer_rating']>=4]
f
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 6         TXN_1006    CUST_103  2023-03-19       2024-06-23  South
# 8         TXN_1008     CUST_75  2023-07-13       2024-04-17   East
# 9         TXN_1009     CUST_88  2023-04-23       2024-08-13  South
# 10        TXN_1010    CUST_117  2023-04-24       2024-06-09  South
# ..             ...         ...         ...              ...    ...
# 994       TXN_1994      CUST_1  2023-02-19       2024-09-13  South
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 1           Home       Prod_D  348.79         5      0.05            UPI
# ...

# %%
data=data.dropna()
data
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ..             ...         ...         ...              ...    ...
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
#calculations::

data['gross_amount']=data['price']*data['quantity']
data
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ..             ...         ...         ...              ...    ...
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
data['discount_amount']=data['gross_amount']*data['discount']
data
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ..             ...         ...         ...              ...    ...
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
data=data.groupby('region')['final_amount'].agg(['sum','min','max','count','mean'])
data
# Out:
#                 sum      min      max  count        mean
# region
# East    142989.5990  11.1400  2347.25    202  707.869302
# North   197881.2170  11.2195  2482.70    274  722.194223
# South   206115.4580  12.1360  2413.00    314  656.418656
# West    138564.5445  10.1970  2453.90    210  659.831164

# %%
data['final_amount']=data['gross_amount']-data['discount_amount']
data
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ..             ...         ...         ...              ...    ...
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
data
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ..             ...         ...         ...              ...    ...
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
f=data.groupby('category')['final_amount'].agg(['sum','count','min','max','mean'])
f
# Out:
#                      sum  count      min      max        mean
# category
# Beauty       146828.0445    209  19.0800  2453.90  702.526529
# Clothing     146894.7260    207  10.1970  2233.00  709.636357
# Electronics  115295.2125    175  11.1400  2347.25  658.829786
# Home         131547.5405    202  12.1360  2242.95  651.225448
# Sports       144985.2950    207  11.2195  2482.70  700.412053

# %%
f=data.groupby('payment_method')['final_amount'].agg(['sum','count','min','max','mean'])
f
# Out:
#                         sum  count      min      max        mean
# payment_method
# Cash             65767.9130     99  10.1970  2453.90  664.322354
# Credit Card     260345.4540    385  11.1400  2482.70  676.221958
# Net Banking     109875.3555    157  12.8700  2413.00  699.843029
# UPI             212961.8210    298  11.2195  2347.25  714.636983
# unknown          36600.2750     61  12.1360  1934.91  600.004508

# %%
data
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ..             ...         ...         ...              ...    ...
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
print(data.dtypes)
# Out:
# transaction_id                 str
# customer_id                    str
# signup_date         datetime64[us]
# transaction_date    datetime64[us]
# region                         str
# category                       str
# product_name                   str
# price                      float64
# quantity                     int64
# discount                   float64
# payment_method                 str
# customer_rating            float64
# gross_amount               float64
# discount_amount            float64
# final_amount               float64
# dtype: object

# %%
data
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ..             ...         ...         ...              ...    ...
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
f=data.groupby('payment_method')['final_amount'].agg(['sum','min','max','count'])
f
# Out:
#                         sum      min      max  count
# payment_method
# Cash             65767.9130  10.1970  2453.90     99
# Credit Card     260345.4540  11.1400  2482.70    385
# Net Banking     109875.3555  12.8700  2413.00    157
# UPI             212961.8210  11.2195  2347.25    298
# unknown          36600.2750  12.1360  1934.91     61

# %%
p=data['price'].max()
p
# Out:
# np.float64(499.53)

# %%
q=data['discount'].max()
q
# Out:
# np.float64(0.2)

# %%
m=data['quantity'].max()
m
# Out:
# np.int64(5)

# %%
s=data['customer_id'].sort_values(ascending=False)
s
# Out:
# 98     CUST_99
# 201    CUST_99
# 214    CUST_99
# 227    CUST_99
# 270    CUST_99
#         ...
# 800     CUST_1
# 838     CUST_1
# 948     CUST_1
# 955     CUST_1
# 994     CUST_1
# Name: customer_id, Length: 1000, dtype: str

# %%
f = data[data['transaction_date'] == '2024-12-29']
f
g=f.groupby('region')['final_amount'].agg(['sum','max'])
g
h=g[g['sum']>=500]
h
m=h[h['max']>=1000]
m
# Out:
#              sum      max
# region
# South   2106.834  1494.92

# %%
f=data['transaction_date'].sort_values()
f
# Out:
# 852   2024-01-01
# 933   2024-01-02
# 689   2024-01-02
# 435   2024-01-03
# 509   2024-01-03
#          ...
# 761   2024-12-30
# 715   2024-12-31
# 775   2024-12-31
# 525   2024-12-31
# 333   2024-12-31
# Name: transaction_date, Length: 1000, dtype: datetime64[us]

# %%
import matplotlib.pyplot as plt

plt.bar(data['region'],data['final_amount'],label='region')

plt.xlabel('region')
plt.ylabel('sum_amount')
plt.title('region wise analysis')
plt.legend()
plt.show()

# %%
plt.barh(data['category'],data['final_amount'],label='category',color='red')
plt.xlabel('sum_amount')
plt.ylabel('region')
plt.title('category wise analysis')
plt.legend()
plt.show()

# %%
data
# Out:
#     transaction_id customer_id signup_date transaction_date region  \
# 0         TXN_1000    CUST_103  2023-11-01       2024-07-20  North
# 1         TXN_1001     CUST_93  2023-10-13       2024-12-10  North
# 2         TXN_1002     CUST_15  2023-05-24       2024-05-25   East
# 3         TXN_1003    CUST_107  2023-01-19       2024-06-12   West
# 4         TXN_1004     CUST_72  2023-01-18       2024-08-29  North
# ..             ...         ...         ...              ...    ...
# 995       TXN_1995    CUST_141  2023-06-01       2024-03-12   West
# 996       TXN_1996    CUST_123  2023-01-19       2024-03-27  North
# 997       TXN_1997     CUST_62  2023-04-10       2024-09-18  North
# 998       TXN_1998     CUST_32  2023-03-01       2024-08-01  North
# 999       TXN_1999     CUST_29  2023-06-16       2024-06-01  South
#
#         category product_name   price  quantity  discount payment_method  \
# 0         Sports       Prod_B  248.82         4      0.20    Net Banking
# ...

# %%
plt.hist(data['customer_rating'])
plt.hist(data['quantity'])
plt.titlt('quantity vs rating')
plt.xlim(1.0,5.0)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[333], line 3
#       1 plt.hist(data['customer_rating'])
#       2 plt.hist(data['quantity'])
# ----> 3 plt.titlt('quantity vs rating')
#       4 plt.xlim(1.0,5.0)
#       5
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'titlt'

# %%
plt.plot(data['final_amount'])
plt.title('final amount analysis')

plt.show()
